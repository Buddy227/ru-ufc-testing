# %% [markdown]
# *ФИО тестировщика:				Февронин Сергей Юрьевич*
#
# https://fsy.atlassian.net/jira/software/projects/UFC10039/boards/1

# %% [markdown]
# **Тестирование сайта https://ru-ufc.com/, который является сайтом мошенником (именно таким его считаю Я), использующий сторонний сайт https://sportrecs.com/ для воспроизведения видеороликов единоборств как платную услугу.**

# %% [markdown]
# *Тестировался сайт посредством ручного тестирования (manual testing). Где Я решил прибегнуть к помощи вспомогательных тулов (tools) - я упомяну в тексте документа. Некоторые приёмы тестирования и тесты будут упомянуты или обозначены, но за неимением времени и возможностей на тестирование, проводится мной не будут. Так как тестирование проводится здесь и сейчас - регрессивное тестирование (regressive testing) проводится не будет. Также в папке с данным документом я приложу ссылку на BugTrackingSystem или файлы с полным планом тест-комплектов. В этом документе Я описываю как Я подходил к тестированию и делаю это для накопления опыта и взаимодействия с «коммунити» (баг допущен специально). Я новичок и junior в тестировании, поэтому всегда ожидаю конструктивную критику в свой адрес. Если у вас есть замечания, предложения, пожелания – пишите мне на электронный ящик fevronin1@mail.ru*

# %% [markdown]
# **СПЕЦИФИКАЦИЯ (SPECIFICATION)**
#
# Спецификации разработки сайта у меня нет, поэтому ориентироваться на документы или требования, посредством которых был выпущен билд (build) сайта, я не имею возможности. Запрашивать информацию у владельцев нет смысла, поэтому начало своего слепого black-box тестирования я приступил с составления небольшого плана сайта и нахождения поддоменов, скрытых страниц сайта для схематичного представления. В дальнейшем я найду с помощью Havij некоторые страницы, которые не должны быть видны пользователю, так как по функционалу и багам очевидно, что это решения из старых билдов.
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/1.png "ShowMyImage")
# Также через дорки не видно эти страницы.
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/2.png "ShowMyImage")
# Решил установить себе небольшой временной период на тестирование и составил checklist:
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/3.png "ShowMyImage")
# Начал провозить позитивное тестирование (positive testing).

# %% [markdown]
# **ПОЗИТИВНОЕ ТЕСТИРОВАНИЕ (POSITIVE TESTING)**
#
# Просмотр одного случайного ролика коротких нарезок роликов доступен на основной странице https://ru-ufc.com/.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/4.png "ShowMyImage")
#
# Кнопка «Войти» вызывает всплывающее окно alert с текстовым полем для ввода номера телефона. При вводе имеющихся у меня номеров операторов МТС и Мегафон (по одному номеру каждого провайдера, в целях сохранности тестовых номеров указывать в этом тест-плане не буду) происходит редирект на https://ru-ufc.com/subscription с похожим textbox по назначению, автозаполнения нет. **Записываю в заметки новую фичу: «Если аккаунт не зарегистрирован в системе, почему бы при редирект’е на страницу регистрации не копировать этот номер в соответствующее текстовое поле?»**
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/5.png "ShowMyImage")
#
#
# Так как я провожу независимое тестирование и, прежде чем отдать деньги предполагаемым «мошенникам», я решил отложить окончательное позитивное тестирование оплаты до выяснения условий предоставления подсписки и безопасности хранимых данных. Ограничился бесплатным просмотром роликов-нарезок боев. Но впоследствии я так и не смог провести позитивное тестирование с двумя имеющимися у меня номерами, так как «Доступ к сайту для вашего оператора не доступен» (необходимо уточнить у продюсера и программиста почему позитивный тест с подходящими номерами не проходит).
# Просмотр роликов происходит в плеере со стороннего сайта. Стоит уточнить у продюсера тестируется ли проигрыватель роликов с сайта партнёра? (В данном случае, наверно, да 😊, но внутреннего доступа у меня нет, поэтому протестировать поддержку разных форматов видео и звука я не могу по понятным причинам.)

# %% [markdown]
# **НЕГАТИВНОЕ ТЕСТИРОВАНИЕ (NEGATIVE TESTING)**
#
# Использую Link Checker и нахожу битые ссылки, отсутсвующие изображения и картинки.
#
# **Записываю баги: «Поправить ошибки битых ссылок и отсутсвующих изображений из отчета
# https://validator.w3.org/checklink?uri=https%3A%2F%2Fru-ufc.com%2F&hide_redirects=on&hide_type=all&recursive=on&depth=5&check=Check#results1».**
# Кнопки отвечают за то, что нужно, нерабочих кнопок нет на формах нет.
#
#
# Страница https://ru-ufc.com/:
#
# Текстовое поле (Textbox) по центру экрана позволяет вводить любые данные, на кнопке (button) «Авторизоваться» стоит проверка на 11 цифр, однако дальше нет никакой проверки – очень весомый баг и дыра в безопасности.
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/6.png "ShowMyImage")
# **Записываю баги: «Textbox «Телефон*» не проверяет входные данные, ожидаемый ввод: номер телефона из цифр без +, фактический результат: 799999999123B». «Кнопка авторизации после первой успешной проверки вводимых данных в текстовое поле (textbox) «Телефон*» перестаёт проверять валидность данных, вводимых в текстовое поле (textbox)»**.
#
#
# Поиск работает корректно, не учитывая регистр букв.
#
# При отсутствии найденных значений ничего не происходит – остаются те же элементы на странице *(это правильное решение, чтобы исключить уязвимость XSS)*; при нажатии крестика «очистить» в поиске – поле поиска становится пустым и возвращает страницу в первоначальный вид (стоит уточнить у продюсера и программиста так ли задумано по спецификации).
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/7.png "ShowMyImage")
#
# Страница https://ru-ufc.com/loginlk:
#
# Текстовое поле (Textbox) по центру экрана позволяет вводить любые данные. Данное поле уязвимо к SQL – injection. **Записываю баг: «Textbox «Введите номер телефона» не проверяет входные данные, ожидаемый ввод: номер телефона из цифр без +»**.
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/8.png "ShowMyImage")

# %% [markdown]
# **ТЕСТИРОВАНИЕ БЕЗОПАСНОСТИ (SECURITY TESTING)**
#
# Тестирование изнутри мне недоступно, поэтому тестирование будет проводиться только снаружи. В виду малого опыта и знаний в данной сфере – буду проводить тестирование известными мне методами и не буду считать тестирование билда (current build) в плане безопасности завершенным (необходимо обратиться за консультацией).
#
# Тестирование начал с разведки.
#
# Файл robots.txt разрешает индексацию всем роботам на все страницы.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/9.png "ShowMyImage")
#
# Вывел заголовки ответа, узнал, что сервер nginx 1.19.0 и принудительно применяется HSTS для всех поддоменов сайта.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/10.png "ShowMyImage")
#
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/11.png "ShowMyImage")
#
# Попробовал вызвать exception на несуществующих страницах, что и, в принципе, удалось. Наткнулся на окно отладки Laravel.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/12.png "ShowMyImage")
#
# Используется MVC Фреймворк Laravel 7.9.2.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/13.png "ShowMyImage")
#
# Покопавшись в доступных строках кода я не смог найти особых уязвимостей отсюда.
# Через подставленные якори удалось вывалить ошибку 404 и узнать хостинг сайта – https://fornex.com/. Однако повторить ошибку не удалось.
# Раскрыл скрытые элементы и увидел пустые поля под параметры запроса на странице подписки. Проверка поля на 11 символов происходит на стороне клиента и это с легкостью можно обойти, изменив значение.
#
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/14.png "ShowMyImage")
#
# Из js файла и отладки Laravel можно сделать предположение что в БД таблица под пользователей вида:
# [type], [url], [async], [username], [password].
# Подстановка на поддоменах в текстовые поля простых запросов вида:

# %% [raw]
# admin' --
# ' HAVING 1=1 –
# UNION SELECT TOP 1 TABLE_NAME FROM INFORMATION_SCHEMA.TABLES—

# %% [markdown]
# Кроме ошибок индексов не даёт результата.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/15.png "ShowMyImage")
#
# Просканировал https://ru-ufc.com/subscription и https://ru-ufc.com/loginlk через SQLi Dumper с 362 дорками – результат отрицательный.
# Дальнейшие действия на этом прекращаю и обращусь за консультацией.
#
# **Выписываю баги: «Не удалены из текущего билда поддомены ru-ufc.com/login, ru-ufc.com/register и thebest2020.ru/web/ru-ufc.com». «Настроить ответы сервера на несуществующие страницы, закрыть доступ к отладке Laravel, пример https://thebest2020.ru/web/ru-ufc.com/landings/land1/?service_id=0»**.

# %% [markdown]
# **ТЕСТИРОВАНИЕ ПОЛЬЗОВАТЕЛЬСКОГО ИНТЕРФЕЙСА (UI TESTING)**
# Выбор следующего элемента с помощью клавиши «TAB» происходит в правильном порядке *слева–направо, сверху–вниз* на всех страницах.
#
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/16.png "ShowMyImage")
#
# При масштабировании шапка (Header) сайта увеличивается на всех страницах, чего не должно происходить. Записываю баг: «При масштабировании шапка сайта не должна изменяться».
# Проверяю HTML и CSS валидаторами. CSS без ошибок, в html стоит поправить некоторые атрибуты в тегах:
#
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/17.png "ShowMyImage")
#
# Используя Расширение Web Developer для Chrome, выставляю разные форматы мобильных телефонов и разрешений. Стоит уточнить у продюсера так ли должен вести себя пользовательский интерфейс.
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/18.png "ShowMyImage")
#
# Смещение при открытии консоли разработчика (клавиша F12) работает корректно.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/19.png "ShowMyImage")
#
# Проверил Кроссбраузерность – присутствует для последних версий Chrome, Firefox и IE. Тестировать различные старые версии браузеров не вижу смысла в данной ситуации при лимите времени, однако делаю уточнение, что в коде js нашел метод и комментарий:

# %% [markdown]
# *//Support: IE <=9 only*
#
# *//IE9 has no XHR2 but throws on binary (trac-11426)*
#
# *//For XHR2 non-text, let the caller handle it (gh-2498)*

# %% [markdown]
# Страница https://ru-ufc.com/:
#
# Footer не закреплён в нижней части окна браузера (считаю это багом, невероятно неудобно листать все ролики сайта донизу чтобы найти правовую информацию). **Записываю баг: «Footer не закреплён к нижней части страницы»**.
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/20.png "ShowMyImage")
# Звездочка «*» в обозначении textbox «Телефон» непонятно к чему ссылается – нет объяснения.**Записываю баг: «Символ звездочка «*» в названии текстового поля «Телефон» непонятно к чему ссылается, добавить объяснение внизу формы»**.
#
# На странице https://ru-ufc.com/subscription:
#
# При уменьшении размера окна по вертикальной оси происходит наложение кнопки Button «Продолжить», Textbox «Номер телефона» выпадает из поля видимости. **Записываю как баг.**
#
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/21.png "ShowMyImage")
#
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/22.png "ShowMyImage")
#
#   ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/23.png "ShowMyImage")
#
# Ссылка (link) «Правила предоставления услуги» не отображается как ссылка. **Записываю как баг.**
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/24.png "ShowMyImage")
#
# Информация в footer’е не объясняет многих вещей:
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/25.png "ShowMyImage")
#
# Что такое платный доступ? **Записываю баг: «Нет информации о платном доступе, добавить информацию о платном доступе»**.
# Каждый день в какой время? **Записываю баг: «Нет информации о списывании средств, добавить информацию о списывании средств в какой период времени»**.
# Не разъяснено что происходит если нет денег на телефоне?  (Не имею возможности провести тест. Ни в одном документе, ни в описаниях на сайте не описан такой исход – UI баг). **Записываю баг: «Нет информации о списывании средств с мобильного счёта, когда нет средств на телефоне, добавить информацию о списывании средств при нулевом балансе»**.
# Работает ли сервис для тех пользователей у кого номер телефона предоставляется ни одним из перечисленных абонентов в footer’e? (Нет возможности провести тест, так как нет сим-карт с номерами телефонов иных операторов). **Записываю баг: «Нет информации о списывании средств с мобильного счёта, когда нулевой баланс (или недостаточно средств на услугу) на телефоне, добавить информацию о списывании средств при нулевом балансе»**.
# Как отписаться клиентам МТС, если личный кабинет или сайт не работает? **Записываю баг: «Нет информации как отписаться пользователям МТС, не используя личный кабинет на сайте, добавить информацию как отписаться пользователям-абонентам МТС»**.
# Подсказка текстового поля на английском языке:
#
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/26.png "ShowMyImage")
#
# **Записываю баг: «Подсказка текстового поля Textbox не русифицирована»**.
#
# Страница https://ru-ufc.com/loginlk:
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/27.png "ShowMyImage")
#
#
# Почему заголовок страницы называется «Авторизация» если это страница для отмены подписки?
#
# **Записываю баг: «Неправильный заголовок страницы (неправильный title), ожидается заголовок «Отмена подписки», фактический «Авторизация»»**.
#
# Страница «адекватно сворачивается» под мобильный экран:
#
# ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/28.png "ShowMyImage")
#
#
# Минимальная достигаемая ширина 150px с открытой консолью разработчика, интерфейс ведёт себя странно - пытается сжаться. Необходимо уточнить у продюсера про поведение в данной ситуации:
#
#  ![title](https://raw.githubusercontent.com/Buddy227/ru-ufc-testing/master/images/29.png "ShowMyImage")

# %% [markdown]
# На этом время вышло, и я закончил тестирование с баг отчетом!
